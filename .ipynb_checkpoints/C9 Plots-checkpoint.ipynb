# %%
import numpy as np
import data_reader as dr
import matplotlib.pyplot as plt
import toolkit as tk
from scipy.optimize import fsolve

# %matplotlib inline

# %%
c9 = dr.sample(r"C:\Users\Scott Reid\Documents\Masters\Research\Data\ErTe3 C9")
c9.add_bridge('X', 44e-6, 8e-6, 2.6e-6)
c9.add_bridge('Y', 44e-6, 8e-6, 2.6e-6)
c9.add_bridge('a', 44e-6, 8e-6, 2.6e-6)
c9.add_bridge('c', 44e-6, 8e-6, 2.6e-6)

# %%
c9.book_files()
# Out:
# 0	ErTe3_C9_0_2017-11-06_12-22-03.dat
# 1	ErTe3_C9_0_2017-11-06_14-47-42.dat
# 2	ErTe3_C9_0_2017-11-06_14-48-08.dat
# 3	ErTe3_C9_0_2017-11-06_15-38-02.dat
# 4	ErTe3_C9_0_2017-11-06_16-08-33.dat
# 5	ErTe3_C9_0_2017-11-06_16-12-23.dat
# 6	ErTe3_C9_0_2017-11-06_16-14-14.dat
# 7	ErTe3_C9_0_2017-11-06_16-18-25.dat
# 8	ErTe3_C9_0_2017-11-06_16-19-40.dat
# 9	ErTe3_C9_0_2017-11-06_16-25-01.dat
# 10	ErTe3_C9_0_2017-11-06_16-30-26.dat
# 11	ErTe3_C9_0_2017-11-06_16-33-21.dat
# 12	ErTe3_C9_0_2017-11-06_16-34-51.dat
# 13	ErTe3_C9_0_2017-11-06_16-37-05.dat
# 14	ErTe3_C9_0_2017-11-06_16-58-25.dat
# 15	ErTe3_C9_0_2017-11-06_17-06-44.dat
# 16	ErTe3_C9_0_2017-11-06_17-07-41.dat
# 17	ErTe3_C9_0_2017-11-06_17-08-10.dat
# 18	ErTe3_C9_0_2017-11-06_17-08-50.dat
# 19	ErTe3_C9_0_2017-11-06_17-14-47.dat
# 20	ErTe3_C9_0_2017-11-06_17-22-26.dat
# 21	ErTe3_C9_0_2017-11-06_17-25-39.dat
# 22	ErTe3_C9_0_2017-11-06_18-18-21.dat
# 23	ErTe3_C9_0_2017-11-06_18-19-12.dat
# 24	ErTe3_C9_0_2017-11-06_18-27-39.dat
# 25	ErTe3_C9_0_2017-11-06_18-34-10.dat
# 26	ErTe3_C9_0_2017-11-06_18-45-57.dat
# 27	ErTe3_C9_0_2017-11-06_19-08-57.dat
# 28	ErTe3_C9_0_2017-11-06_19-11-49.dat
# 29	ErTe3_C9_0_2017-11-06_20-31-28.dat
# 30	ErTe3_C9_0_2017-11-06_20-45-30.dat
# 31	ErTe3_C9_0_2017-11-06_22-08-57.dat
# 32	ErTe3_C9_0_2017-11-06_22-13-38.dat
# 33	ErTe3_C9_0_2017-11-06_22-20-54.dat
# 34	ErTe3_C9_0_2017-11-06_22-22-48.dat
# 35	ErTe3_C9_0_2017-11-06_22-25-21.dat
# 36	ErTe3_C9_0_2017-11-06_23-22-40.dat
# 37	ErTe3_C9_0_2017-11-06_23-53-38.dat
# 38	ErTe3_C9_0_2017-11-06_23-58-03.dat
# 39	ErTe3_C9_0_2017-11-07_11-47-56.dat
# 40	ErTe3_C9_0_2017-11-07_12-17-35.dat
# 41	ErTe3_C9_0_2017-11-07_12-43-12.dat
# 42	ErTe3_C9_0_2017-11-07_13-21-09.dat
# 43	ErTe3_C9_0_2017-11-07_13-25-19.dat
# 44	ErTe3_C9_0_2017-11-07_13-30-43.dat
# 45	ErTe3_C9_0_2017-11-07_13-38-36.dat
# 46	ErTe3_C9_0_2017-11-07_13-47-59.dat
# 47	ErTe3_C9_0_2017-11-07_14-36-10.dat
# 48	ErTe3_C9_0_2017-11-07_14-45-28.dat
# 49	ErTe3_C9_0_2017-11-07_14-47-10.dat

# %% [markdown]
# # Important runs:
# ### R vs. T:
# - 2 (295K - 255K)
# - 21 (255K - 205K)
# - 40 (295 - 190)
# - 41 (190 - 120, contact jumps)
#
# ### Sliding at 255K:
# - 6 (diagonal??)
# - 8 (c)
# - 13 (diagonal)
# - 14 (diagonal)
# - 18 (a axis)
# - 19 (c axis)
#
# ### Sliding at 205K:
# - 23 (c axis)
# - 24 (a axis)
# - 25 (a axis, c axis disconnected)
# - 26 (diagonal)
# - 28 (plane)
# - 29 (diagonal)
# - 30 (plane in diagonal config)
#
# ### Attempted Sliding at 120K
# - 42, 43, 44, 45, 46, 47
# - 48, 49 (contact failure)
#
# ### Offset R vs. T
# - 35 (235 - 295)
# - 33, 34 also
#
# ### Heating at 295 K
# - 36 (plane)
# - 38 (plane)

# %% [markdown]
# # (1) R vs. T: Finding the parallel resistance across the c axis voltage contacts

# %%
d, _ = c9.get_dat(2) #R vs. T data
d = d[np.logical_not(np.isnan(d['VXX']))]
rm = d['VXX']/d['IX']
ra = d['VYX']/d['IY']

fig, ax = plt.subplots(figsize = (10,7))
plt.plot(d['TA'], rm, 'r', label = 'c axis')
plt.plot(d['TA'], ra, 'k', label = 'a axis')
plt.ylim([0,0.5])
plt.legend(fontsize = 14)
plt.xlabel('Temperature (K)', fontsize = 14)
plt.ylabel('Resistance ($\Omega$)', fontsize = 14)
plt.title('Uncorrected R vs. T', fontsize = 14)

# %%
d = c9.get_dat(2)[0]
d = d[np.logical_not(np.isnan(d['VXX']))]
rm = d['VXX']/d['IX']
ra = d['VYX']/d['IY']

rp = rm*ra/(ra - rm)
cut = (d['TA'] > 270) & (d['TA'] < 285)
po = np.polyfit(d['TA'][cut], rp[cut], 1)

fig, ax = plt.subplots(figsize = (10,7))
plt.plot(d['TA'][d['TA'] > 270], rp[d['TA'] > 270])
plt.plot(d['TA'][d['TA'] > 270], po[1] + po[0]*d['TA'][d['TA'] > 270])
plt.xlabel('Temperature (K)', fontsize = 14)
plt.ylabel('Resistance ($\Omega$)', fontsize = 14)
plt.title('Parallel resistance of the c-axis channel', fontsize = 14)

# %%
print(po)
# Out:
# [ 0.00020898  0.12384713]

# %% [markdown]
# $R_p(T) = 124 m\Omega + 0.209 m\Omega/K$

# %%
# Calculates the parallel resistance across the c voltage terminals
def Rp(T):
    return 0.12384713 + 0.00020898 * T

# Calculates the actual resistal c resistance
def Rc(rm, T):
    return Rp(T)*rm/(Rp(T) - rm)

# %%
d, _ = c9.get_dat(2) #R vs. T data
d = d[np.logical_not(np.isnan(d['VXX']))]
rm = d['VXX']/d['IX']
ra = d['VYX']/d['IY']

fig, ax = plt.subplots(figsize = (10,7))
plt.plot(d['TA'], Rc(rm, d['TA']), 'r', label = 'c axis')
plt.plot(d['TA'], ra, 'k', label = 'a axis')
plt.legend(fontsize = 14)
plt.xlabel('Temperature (K)', fontsize = 14)
plt.ylabel('Resistance ($\Omega$)', fontsize = 14)
plt.title('Corrected R vs. T', fontsize = 14)

# %%
d = c9.get_dat(35)[0]
ra = d['VYX']/d['IY']
rm = d['VXX']/d['IX']
fig, ax = plt.subplots(figsize = (10,7))
plt.plot(d['TA'], Rc(rm, d['TA']), 'r', label = 'c axis')
plt.plot(d['TA'], ra, 'k', label = 'a axis')
plt.legend(fontsize = 14)
plt.xlabel('Temperature (K)', fontsize = 14)
plt.ylabel('Resistance ($\Omega$)', fontsize = 14)
plt.title('Corrected R vs. T', fontsize = 14)

# %%
d = c9.get_dat(40)[0]
ra = d['VYX']/d['IY']
rm = d['VXX']/d['IX']
fig, ax = plt.subplots(figsize = (10,7))
plt.plot(d['TA'], Rc(rm, d['TA']), 'r', label = 'c axis')
plt.plot(d['TA'], ra, 'k', label = 'a axis')
plt.legend(fontsize = 14)
d = c9.get_dat(41)[0]
ra = d['VYX']/d['IY']
rm = d['VXX']/d['IX']
plt.plot(d['TA'], Rc(rm, d['TA']), 'r', label = 'c axis')
plt.plot(d['TA'], ra, 'k', label = 'a axis')
plt.xlabel('Temperature (K)', fontsize = 14)
plt.ylabel('Resistance ($\Omega$)', fontsize = 14)
plt.title('Corrected R vs. T (from day 2 -- Would need different fit)', fontsize = 14)
plt.ylim(0, 0.5)
# Out:
# (0, 0.5)

# %% [markdown]
# Moral of the story: there is a parallel resistance that can be modeled as $R_p(T) = 109 m\Omega + 0.262 m\Omega/K$ across the c-axis voltage terminals

# %% [markdown]
# # (2) Measuring sliding along the a axis bridge (205 K)

# %%
d, _ = c9.get_dat(24)
siga = tk.conductivity(v=d['VYX'], i = d['IY'], bridge = c9.b('a'))
i = d['IYO']
e = tk.E_field(l=c9.bl('a'), i=d['IY'], io = d['IYO'], v=d['VYX'])
T = d['TA'][0]
rp = Rp(T)

fig, ax = plt.subplots(figsize = (10,7))
plt.plot(e, 1/siga*1e6)
plt.xlabel('$E_a$ (V/m)', fontsize = 14)
plt.ylabel(r'$\rho_a^*$ ($\mu\Omega$/m)', fontsize = 14)
plt.title('a axis sliding differential resistivity at 205 K', fontsize = 14)

# %%
plt.plot(d['IYO'], d['VXX'])
plt.ylabel('c axis voltage')
plt.xlabel('a axis current')

# %% [markdown]
# Clearly, the a axis is sliding when a threshold field of 20 V/m is reached. No effect on the c axis bridge.

# %% [markdown]
# # (3) Weak c axis sliding
#
# The current pathway along the c-axis bridge includes regions where the current is at high and low densities; thus, threshold field is reached in some regions and not in others. We may have inadvertantly done an experiment that can observe long-range effects.
# <img src="parallel_R.png">
# We look at data from 205 K sliding

# %%
def c_cond(v, i, T):
    return 1/Rc(v/i, T)*c9.b('c')

def c_e(v, i, io, T):
    return tk.E_field(io, )

# %%
d, _ = c9.get_dat(23)
i = d['IXO']
T = d['TA'][0]
sigc = c_cond(d['VXX'], d['IX'], T)


fig, ax = plt.subplots(figsize = (10,7))
plt.plot(i*1000, 1/sigc*1e6)
plt.xlabel('$I_c$ (mA)', fontsize = 14)
plt.ylabel(r'dE/dJ ($\mu\Omega$/m)', fontsize = 14)
plt.title('c axis sliding differential resistivity at 205 K', fontsize = 14)

# %% [markdown]
# # (4) No correlation in Monceau Planes - Independent Sliding

# %%
d = c9.get_dat(28)[0]

n = int(np.sqrt(len(d['IYO'])))
yr = np.arange(min(d['IYO']), max(d['IYO']), (max(d['IYO']) - min(d['IYO']))/n)
xr = np.arange(min(d['IXO']), max(d['IXO']), (max(d['IXO']) - min(d['IXO']))/n)

y, x = np.meshgrid(yr, xr)
z1 = (d['VYX']/d['IY']).reshape(n, n)
z2 = Rc(rm=d['VXX']/d['IX'], T = 205).reshape(n,n)

fig, ax = plt.subplots()
ax = plt.pcolor(x*1e3,y*1e3,z1)
fig.colorbar(ax, label = '$R_a$ ($\Omega$)')
plt.xlabel('c axis current (mA)')
plt.ylabel('a axis current (mA)')
plt.title('a axis 205 K Monceau plane')

fig, ax = plt.subplots()
ax = plt.pcolor(x*1e3,y*1e3,z2)
fig.colorbar(ax, label = '$R_c$ ($\Omega$)')
plt.xlabel('c axis current (mA)')
plt.ylabel('a axis current (mA)')
plt.title('c axis 205 K Monceau plane')

# %% [markdown]
# # (5) TODO Modeling Heating

# %% [markdown]
# # (6) Resistivities, Sliding Resistivities, and Extraconductivities over T
#
# ### TODO:
# (1) Give seperate temperature arrays for each offset/measurement <br>
# (2) Incorporate heating model

# %%
def read_offsets(ns):
    t = np.ndarray(0)
    sigao = np.ndarray(0)
    sigac = np.ndarray(0)
    sigco = np.ndarray(0)
    sigcc = np.ndarray(0)
    
    for n in ns:
        d, _ = c9.get_dat(n)
        T = d['TA']
        siga = tk.conductivity(bridge = c9.b('a'), i = d['IY'], v = d['VYX'])
        sigc = c_cond(d['VXX'], d['IX'], T)
        tt = T[(d['IYO'] == 0) & (d['IXO'] == 0)]
        ao = siga[(d['IYO'] == 0) & (d['IXO'] == 0)]
        ac = siga[d['IYO'] != 0]   
        co = sigc[(d['IYO'] == 0) & (d['IXO'] == 0)]
        cc = sigc[d['IXO'] != 0]
        
        l = np.min([len(tt), len(ao), len(ac), len(cc)])
        t = np.concatenate((t, tt[0:l]))
        sigao = np.concatenate((sigao, ao[0:l]))
        sigac = np.concatenate((sigac, ac[0:l]))
        sigco = np.concatenate((sigco, co[0:l]))
        sigcc = np.concatenate((sigcc, cc[0:l]))
    return t, sigao, sigac, sigco, sigcc

def read_offsets_c(ns):
    t = np.ndarray(0)
    sigco = np.ndarray(0)
    sigcc = np.ndarray(0)
    
    for n in ns:
        d, _ = c9.get_dat(n)
        T = d['TA']
        sigc = c_cond(d['VXX'], d['IX'], T)
        tt = T[(d['IYO'] == 0) & (d['IXO'] == 0)]
        co = sigc[(d['IYO'] == 0) & (d['IXO'] == 0)]
        cc = sigc[d['IXO'] != 0]
        
        l = np.min([len(tt), len(co), len(cc)])
        t = np.concatenate((t, tt[0:l]))
        sigco = np.concatenate((sigco, co[0:l]))
        sigcc = np.concatenate((sigcc, cc[0:l]))
    return t, sigco, sigcc

# %%
t, sigao, sigac, sigco, sigcc = read_offsets([31, 34, 35])
tt, sigcot, sigcct = read_offsets_c([33,34,35])

# %%
fig, ax = plt.subplots(figsize = (8,5))
d, _ = c9.get_dat(24)
siga = tk.conductivity(v=d['VYX'], i = d['IY'], bridge = c9.b('a'))
i = d['IYO']
plt.plot(t, 1/sigao*1e6, 'k.', label = 'a axis resistivity', ms = 2)
plt.plot(t, 1/sigac*1e6, 'r.', label = 'a axis sliding resistivity', ms = 2)
plt.plot(205, 1e6/siga[i==0], 'k.')
plt.plot(205, 1e6/siga[0], 'r.')
plt.legend()
plt.xlabel('T (K)')
plt.ylabel(r'$\rho$ ($\mu\Omega$/m)')
plt.title('A Axis')

# %%
fig, ax = plt.subplots(figsize = (8,5))
plt.plot(t, (sigac-sigao)*1e-6, 'k.', ms = 2)
plt.plot(205, .286, 'kX')
plt.xlabel('T (K)')
plt.ylabel('$\sigma$ (S/$\mu$m)')
plt.title('A Axis Sliding Extraconductivity')

# %%
fig, ax = plt.subplots(figsize = (8,5))
d, _ = c9.get_dat(23)
i = d['IXO']
T = d['TA'][0]
sigc = c_cond(d['VXX'], d['IX'], T)
plt.plot(tt, 1/sigcot*1e6, 'k.', label = 'c axis resistivty', ms = 2)
plt.plot(tt, 1/sigcct*1e6, 'r.', label = 'c axis sliding resistivity', ms = 2)
plt.plot(T, 1e6/sigc[i==0], 'k.')
plt.plot(T, 1e6/sigc[0], 'r.')
plt.legend()
plt.xlabel('T (K)')
plt.ylabel(r'$\rho$ ($\mu\Omega$/m)')
plt.title('C Axis')

# %%
fig, ax = plt.subplots(figsize = (8,5))
plt.plot(tt, (sigcct-sigcot)*1e-6, 'k.')
plt.plot(205, 0.108, 'kX')
plt.xlabel('T (K)')
plt.ylabel('$\sigma$ (S/$\mu$m)')
plt.title('C Axis Sliding Extraconductivity')

# %%
fig, ax = plt.subplots(figsize = (8,6))
plt.plot(t, 1/sigao*1e6, 'r.', label = 'a axis resistivity', ms = 2)
plt.plot(t, 1/sigac*1e6, 'm.', label = 'a axis sliding resistivity', ms = 2)
d, _ = c9.get_dat(24)
siga = tk.conductivity(v=d['VYX'], i = d['IY'], bridge = c9.b('a'))
i = d['IYO']
plt.plot(205, 1e6/siga[i==0], 'r.', ms = 8)
plt.plot(205, 1e6/siga[0], 'm.', ms = 8)
plt.plot(tt, 1/sigcot*1e6, 'b.', label = 'c axis resistivty', ms = 2)
plt.plot(tt, 1/sigcct*1e6, 'c.', label = 'c axis sliding resistivity', ms = 2)
d, _ = c9.get_dat(23)
i = d['IXO']
T = d['TA'][0]
sigc = c_cond(d['VXX'], d['IX'], T)
plt.plot(205, 1e6/sigc[i==0], 'b.')
plt.plot(205, 1e6/sigc[0], 'c.')
plt.legend()
plt.xlabel('T (K)')
plt.ylabel(r'$\rho$ ($\mu\Omega$/m)')

# %%
fig, ax = plt.subplots(figsize = (8,5))
plt.plot(t, (sigac-sigao)*1e-6, 'r.', ms = 2)
plt.plot(205, .286, 'rs')
plt.plot(tt, (sigcct-sigcot)*1e-6, 'k.', ms = 2)
plt.plot(205, 0.108, 'ks')
plt.xlabel('T (K)')
plt.ylabel('$\sigma$ (S/$\mu$m)')
plt.title('Sliding Extraconductivity')

# %% [markdown]
# # (7) *Speculative* a Sliding Length Scale
#
# ### TODO:
# (1) Improve by incorporating heating model, different temperature interpolation <br>
# (3) Put on plot alongside sliding extraconductivity <br>
# (4) Mean free path model (exponential)???

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %%
#BLOCK SLIDING MODEL

def L(ns):
    t, sigao, sigac, sigco, sigcc = read_offsets(ns)
    
    rhom = 1/sigcc
    rho = 1/sigco
    rhoc = 1/(sigco + sigac - sigao)
    lo = 44
    
    return t, lo/2 * (rhom - rho)/(rhoc - rho)

# %%
fig, ax = plt.subplots(figsize = (8,5))
t, l = L([34, 35])
l = l[t < 270]
t = t[t < 270]
# plt.plot(t, l, 'k.')
plt.plot(205, 8.6, 'kX')
# sl = smooth(l,2)
plt.plot(t, l, 'k.')
plt.plot(t[t < 268], -1/(.02*(t - 268))[t<268] + 2.5, 'r--')
ts = np.array([205, 240])
plt.plot(ts, 8.6 - 0.15*(ts - 205), '--')
# plt.plot([205, t[0]], [8.6, sl[4]])
plt.ylim([0,30])
plt.xlabel('T (K)')
plt.ylabel('L ($\mu$m)')
plt.title('Sliding Correlation Length?')

# %% [markdown]
# Note: need to factor heating effects into my consideration, and also consider the possibility of fringe effects or sliding in the voltage contacts themselves.

# %%
#MEAN FREE PATH METHOD
#THERE ARE PROBLEMS WITH THIS METHOD AS OF NOW

def L2(d):
    T = d['TA']
    siga = tk.conductivity(bridge = c9.b('a'), i = d['IY'], v = d['VYX'])
    sigc = c_cond(d['VXX'], d['IX'], T)

    t = T[(d['IYO'] == 0) & (d['IXO'] == 0)]
    sigao = siga[(d['IYO'] == 0) & (d['IXO'] == 0)]
    sigac = siga[d['IYO'] != 0]

    sigco = sigc[(d['IYO'] == 0) & (d['IXO'] == 0)]
    sigcc = sigc[d['IXO'] != 0]
    
    rho = 1/sigco
    sigc = sigac - sigao
    rhom = 1/sigcc
    Lo = 44
    
    a = rho*sigc
    b = rhom/rho
    
    x = np.ndarray(len(a))
    for i in range(len(a)):
        func = lambda x : (1+a[i])*x**b[i] - (x+a[i])
        x_guess = 0.5
        x[i] = fsolve(func, x_guess)
    
    return Lo/(2*np.log(x))

# %% [markdown]
# # (8) Other explanations for c axis extraconductivity:
#
# (1) Fringe effects at contacts -> hard to model, but what would the extraconductivity have to be in the contacts to explain the whole effect? <br>
# (2) Heating... does not explain everything, but perhaps it explains something <br>
# (3) Something in the parallel resistor?
